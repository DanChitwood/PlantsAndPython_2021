# %% [markdown]
# ## Above vs below

# %%
from openTSNE import TSNE
from examples import utils
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("data/result_table_100.csv")

# %%
data = data[data["UniqueMappedRatio"] > 0.75]
data = data[data["Tissue"] != "--"]

# %%
data["Tissue"].value_counts()
# Out:
# seedlings         3990
# leaves            3474
# root              1287
# rosette leaf      1074
# shoot              538
#                   ...
# 7DAG seedlings       1
# root and shoot       1
# root cap cells       1
# mesophyll            1
# cortex               1
# Name: Tissue, Length: 85, dtype: int64

# %%
import re
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

text = data["Tissue"]

unique_string=(" ").join(text)
wordcloud = WordCloud(width = 1000, height = 500).generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig("your_file_name"+".png", bbox_inches='tight')
plt.show()
plt.close()

# %%
#df[df.name.str.match(regex)]

data[data["Tissue"].str.contains("root")] = "root"
data[data["Tissue"].str.contains("lea")] = "leaves"
data[data["Tissue"].str.contains("shoot")] = "leaves"
data[data["Tissue"].str.contains("pistil")]
# Out:
#            Sample                                         SampleName  \
# 10318  SRX1960065   Arabidopsis thaliana, Cvi-0 Unpollinated Pistils
# 10319  SRX1960066   Arabidopsis thaliana, Cvi-0 Unpollinated Pistils
# 10320  SRX1960103   Arabidopsis thaliana, Cvi-0 Unpollinated Pistils
# 10321  SRX1960214  Arabidopsis thaliana, Cvi-0 x Cvi-0, 8 hour po...
# 10322  SRX1960313  Arabidopsis thaliana, Cvi-0 x Cvi-0, 8 hour po...
# 10323  SRX1960395  Arabidopsis thaliana, Cvi-0 x Cvi-0, 8 hour po...
# 10324  SRX1960452  Arabidopsis thaliana, Col-0 x Col-0, 8 hour po...
# 10325  SRX1960507  Arabidopsis thaliana, Col-0 x Col-0, 8 hour po...
# 10326  SRX1960508  Arabidopsis thaliana, Col-0 x Col-0, 8 hour po...
# 10327  SRX1960573  Arabidopsis thaliana, Cvi-0 x Col-0, 8 hour po...
# 10328  SRX1960611  Arabidopsis thaliana, Cvi-0 x Col-0, 8 hour po...
# 10329  SRX1960653  Arabidopsis thaliana, Cvi-0 x Col-0, 8 hour po...
# 10330  SRX1960730  Arabidopsis thaliana, Cvi-0 x myb97, myb101, m...
# ...

# %%
leaves = data[data["Tissue"].str.contains("flower")]
leaves["Tissue"].unique()
# Out:
# array(['flower bud', 'flower', 'flower receptacles', 'flower meristems'],
#       dtype=object)
