# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
#Gradient Boosting model
# test classification dataset
from sklearn.datasets import make_classification
# evaluate gradient boosting algorithm for classification
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
urlfile="https://raw.githubusercontent.com/DanChitwood/PlantsAndPython_2021/main/Machine%20Learning/result_table_100_24_tissues.csv"

df = pd.read_csv(urlfile)
# Extract Tissue column
labels = df["Tissue"].values

label_encoder = LabelEncoder().fit(np.unique(labels))
df['Tissue'] = label_encoder.transform(labels)

# %%
df.head()
# Out:
#       Sample SampleName  AT1G06190  AT1G59830  AT4G05510  AT5G45573  \
# 0  DRX014481         Y1      31.10      45.58        0.0        0.0
# 1  DRX014482         Y2      29.71      40.16        0.0        0.0
# 2  DRX014483         Y9      28.65      37.61        0.0        0.0
# 3  DRX014484        Y10      26.74      42.09        0.0        0.0
# 4  DRX014485        Y11      26.35      37.27        0.0        0.0
#
#    AT1G18340  AT4G13770  AT1G05520  AT1G48580  ...  AT5G61500  AT5G00910  \
# 0      29.47      51.06      26.40       7.32  ...      57.13       0.54
# 1      26.99      46.15      31.74       9.03  ...      49.69       0.38
# 2      26.93      41.27      34.48      11.03  ...      45.91       0.34
# 3      25.64      40.41      34.70       5.36  ...      52.55       0.72
# 4      25.91      38.70      35.68       6.47  ...      45.96       0.56
#
#    Tissue  Ecotype   Genotype  Treatment    Project  TotalReads  \
# 0      13       --  wild type         --  PRJDB1593    95012910
# 1      13       --  wild type         --  PRJDB1593   163269003
# 2      13       --     max1-1         --  PRJDB1593   182427758
# 3      13       --     max1-1         --  PRJDB1593   109750057
# 4      13       --     max1-1         --  PRJDB1593   167993289
#
#    UniqueMappedRatio  ReleaseDate
# 0             0.8982     2016/2/5
# 1             0.9293     2016/2/5
# 2             0.9305     2016/2/5
# 3             0.9298     2016/2/5
# 4             0.9242     2016/2/5
#
# [5 rows x 110 columns]

# %%
#assign X and Y variables
X = df.iloc[:, 2:103].values
y = df.iloc[:, 103].values

#Define features
kf = KFold(n_splits=5,random_state=42,shuffle=True)
train_percent = 0.75
# create training and testing subsets
train = np.random.choice(a=[True, False], size=len(y), p=[train_percent, 1-train_percent])
test = np.invert(train)
for train_index,val_index in kf.split(X):
    X_train,X_test = X[train],X[test],
    y_train,y_test = y[train],y[test]

# %%
#Model    
gradient_booster = GradientBoostingClassifier(learning_rate=0.1, max_depth=20, random_state=10)

# %%
#fit the model
GB_fit=gradient_booster.fit(X_train,y_train)
#Accuracy
print(classification_report(y_test,gradient_booster.predict(X_test)))

# %%
#Visualizing
plt.figure(figsize=(12,8)) 
tree.plot_tree(GB_fit, filled=True, fontsize=10)
plt.show()
